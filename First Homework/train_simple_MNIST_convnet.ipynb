# %% [markdown]
# ## Setup

# %%
import numpy as np
import keras
import pathlib
from keras import layers
from scipy.ndimage import rotate

# %% [markdown]
# ## Prepare the data

# %%
# Model / data parameters
num_classes = 10
input_shape = (28, 28, 1)

# Load the data and split it between train and test sets
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

#x_train_90 = np.array([rotate(img, 90, reshape=False) for img in x_train])
#x_train_180 = np.array([rotate(img, 180, reshape=False) for img in x_train])
#x_train_270 = np.array([rotate(img, 270, reshape=False) for img in x_train])
#y_train_90 = y_train.copy()
#y_train_180 = y_train.copy()
#y_train_270 = y_train.copy()
#x_train_augmented = np.concatenate([x_train, x_train_90, x_train_180, x_train_270])
#y_train_augmented = np.concatenate([y_train, y_train_90, y_train_180, y_train_270])
#
#x_test_90 = np.array([rotate(img, 90, reshape=False) for img in x_test])
#x_test_180 = np.array([rotate(img, 180, reshape=False) for img in x_test])
#x_test_270 = np.array([rotate(img, 270, reshape=False) for img in x_test])
#y_test_90 = y_test.copy()
#y_test_180 = y_test.copy()
#y_test_270 = y_test.copy()
#x_test_augmented = np.concatenate([x_test, x_test_90, x_test_180, x_test_270])
#y_test_augmented = np.concatenate([y_test, y_test_90, y_test_180, y_test_270])


# Scale images to the [0, 1] range
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255
# Make sure images have shape (28, 28, 1)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
print("x_train_augmented shape:", x_train.shape)
print(x_train.shape[0], "train samples")
print(x_test.shape[0], "test samples")


# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train_augmented shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %% [markdown]
# ## Build the model

# %%
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        #layers.Conv2D(32, kernel_size=(3, 3), activation='relu'),
        #layers.MaxPooling2D(pool_size=(2, 2)),
        #layers.Dropout(0.25),
#
        #layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
        #layers.MaxPooling2D(pool_size=(2, 2)),
        #layers.Dropout(0.25),
#
        #layers.Flatten(),
        #layers.Dense(128, activation='relu'),
        #layers.Dropout(0.5),
        #layers.Dense(10, activation='softmax')

        layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(64, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation="softmax"),
    ]
)

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 1600)           │             0 │
# ...

# %% [markdown]
# ## Train the model

# %%
batch_size = 128
epochs = 15

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)
# Out:
# Epoch 1/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.8887 - loss: 0.3626 - val_accuracy: 0.9792 - val_loss: 0.0792
# Epoch 2/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.9653 - loss: 0.1117 - val_accuracy: 0.9823 - val_loss: 0.0597
# Epoch 3/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9738 - loss: 0.0841 - val_accuracy: 0.9880 - val_loss: 0.0457
# Epoch 4/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.9782 - loss: 0.0708 - val_accuracy: 0.9887 - val_loss: 0.0402
# Epoch 5/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9806 - loss: 0.0629 - val_accuracy: 0.9870 - val_loss: 0.0406
# Epoch 6/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9826 - loss: 0.0557 - val_accuracy: 0.9868 - val_loss: 0.0409
# Epoch 7/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9841 - loss: 0.0500 - val_accuracy: 0.9895 - val_loss: 0.0354
# Epoch 8/15
# ...

# %% [markdown]
# ## Evaluate the trained model

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Test loss: 0.024044623598456383
# Test accuracy: 0.9923999905586243

# %% [markdown]
# ## Save the model

# %%
path_model: pathlib.Path = pathlib.Path.cwd().joinpath('trained_mnist_modell.keras')
model.save(filepath=path_model)
